# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
import glob

# TODO: Load all insights to a single dataframe.
path = "../data/periodic_data"
all_files = glob.glob(path + "/*.csv")
insights = pd.concat((pd.read_csv(f) for f in all_files))

insights
# Out:
#      2019-11-01     91  442  236    0   8   9
# 0    2019-11-02   44.0  NaN  NaN  NaN NaN NaN
# 1    2019-11-03  132.0  NaN  NaN  NaN NaN NaN
# 2    2019-11-04  184.0  NaN  NaN  NaN NaN NaN
# 3    2019-11-05  119.0  NaN  NaN  NaN NaN NaN
# 4    2019-11-06  210.0  NaN  NaN  NaN NaN NaN
# ..          ...    ...  ...  ...  ...  ..  ..
# 258  2020-07-17    NaN  NaN  NaN  0.0 NaN NaN
# 259  2020-07-18    NaN  NaN  NaN  0.0 NaN NaN
# 260  2020-07-19    NaN  NaN  NaN  0.0 NaN NaN
# 261  2020-07-20    NaN  NaN  NaN  0.0 NaN NaN
# 262  2020-07-21    NaN  NaN  NaN  0.0 NaN NaN
#
# [2367 rows x 7 columns]

# %% [markdown]
# ### Daily Reach and Follower count analysis

# %%
for col in follower_count.columns:
    if(col != 'Date'):
        plt.scatter(follower_count[col], reach[col], label = col)

plt.legend(loc='best', fontsize=16)
plt.xlabel('Follower count %')
plt.ylabel('Reach');
